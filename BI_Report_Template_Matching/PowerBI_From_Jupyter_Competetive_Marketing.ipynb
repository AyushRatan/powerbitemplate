# %%
#Notes - This Notebook is just a clone of v4, but minimal changes that are being carried out are w.r.t other PBI reports.

# %%
import os
import time
import pandas as pd
from powerbiclient import Report, models
from powerbiclient.authentication import InteractiveLoginAuthentication
device_auth = InteractiveLoginAuthentication()
# Out:
# A local browser window will open for interactive sign in.
#
# Interactive authentication successfully completed.
# You are now logged in.
#
# The result should be passed only to trusted code in your notebook.

# %%
#Competetive_Marketing
group_id = "653fc201-df39-4f8d-9bb1-b9de4e2b03be"
report_id = "cdafa5e7-5dc1-4113-983c-043fd3f557b4"

# %%
report = Report(group_id = group_id, report_id = report_id, auth = device_auth)
report
# Out:
# Report()

# %%
report_pages=report.get_pages()
Page_id = []
Page_Name = []
Visual_ID = []
Visualization = []
Title = []

folder_name = "POC_Competetive_Marketing"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

for report_page in report_pages:
    if report_page['visibility'] == 0 and report_page['isActive'] == True:
        #print(f"Page_id: {report_page['name']}, Page_Name: {report_page['displayName']}, Visibility: {report_page['visibility']}")
        Page_id.append(report_page['name'])
        Page_Name.append(report_page['displayName'])
        report_visuals=report.visuals_on_page(report_page["name"])
        for report_visual in report_visuals:
            try:
                title = report_visual['title']
            except:
                title = None

            #print(f"Visual ID: {report_visual['name']}, Visualization Type:{report_visual['type']}, Title: {title}")
            Visual_ID.append(report_visual['name'])
            Visualization.append(report_visual['type'])
            Title.append(title)
            

Page_id = Page_id * len(Visual_ID)
Page_Name = Page_Name * len(Visual_ID)
data = list(zip(Page_id, Page_Name, Visual_ID, Visualization, Title))
df = pd.DataFrame(data, columns=["Page_id", "Page_Name", "Visual_ID", "Visualization", "Title"])
#file_path = os.path.join(folder_name, f"POC_Corporate_Spend_{report_page['displayName']}_VisualMetaData.csv")
#df.to_csv(file_path)

# %%
dont_consider = ["actionButton", "basicShape", "shape", "textbox"]
df1 = df[~df["Visualization"].isin(dont_consider)]
df1
# Out:
#                               Page_id           Page_Name  \
# 0   ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 7   ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 8   ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 9   ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 10  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 11  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 13  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 14  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 15  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 16  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 17  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 18  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 20  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 31  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 37  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 38  ReportSectione0912ffb2ba909ea50d0  Executive Overview
# 39  ReportSectione0912ffb2ba909ea50d0  Executive Overview
#
#                Visual_ID                Visualization  \
# 0   01e0089059a26da6b0a9                 multiRowCard
# 7       VisualContainer6  lineStackedColumnComboChart
# 8   8c4d5fd430d238c80232                 multiRowCard
# 9   383aeb4a890ab3b0602c                 multiRowCard
# 10  c1fcec8fbd3489c06b5c                 multiRowCard
# 11  c6f0f21b6e8eeeca780e                 multiRowCard
# 13  b3ce93b93cba452a50d4                   donutChart
# 14  601d2ae47d1962782c20                         card
# 15  beef72ba5205ba2613d1                         card
# 16  bfabe4ecb6017dc44b75                         card
# 17  6e130c7362a050c78ee3                         card
# 18  918a74069a7dac914785                         card
# 20  22d233e1510db7d1c3a4                     barChart
# 31  7431bd1ddf78313f3a1b                        image
# 37      VisualContainer4                     barChart
# 38      VisualContainer3                    lineChart
# 39      VisualContainer1         clusteredColumnChart
#
#                                                 Title
# 0                                      Multi-row card
# 7                    Total Sales by Channel Over Time
# 8                                      Multi-row card
# 9                                      Multi-row card
# 10                                     Multi-row card
# 11                                     Multi-row card
# 13                             Total Sales by Channel
# 14                                       Outlet Sales
# 15                                       Stores Sales
# 16                                 Social Media Sales
# 17                                       Online Sales
# 18                                        Total Sales
# 20  % Units Market Share R12M and % Units Market S...
# 31                                              Image
# 37                 Total Sales by Product and Channel
# 38  % Units Market Share R12M and % Units Market S...
# 39         Total Units by Year, Month and isVanArsdel

# %%
dont_consider = ["actionButton", "basicShape", "shape", "textbox"]
df2 = df[~df["Visualization"].isin(dont_consider)]
df2
# Out:
#                               Page_id       Page_Name             Visual_ID  \
# 0   ReportSection7b10a3902b9749b440a7  Top 10 Regions  25c7bcab60c1e6a83e95
# 1   ReportSection7b10a3902b9749b440a7  Top 10 Regions  6dcbb33b0023ad4a8b7d
# 2   ReportSection7b10a3902b9749b440a7  Top 10 Regions  411d5777020c9b511dee
# 3   ReportSection7b10a3902b9749b440a7  Top 10 Regions  90df334e48300593891d
# 4   ReportSection7b10a3902b9749b440a7  Top 10 Regions  c880775270c2c6801780
# 5   ReportSection7b10a3902b9749b440a7  Top 10 Regions  69cd67e0bdd308b1910c
# 6   ReportSection7b10a3902b9749b440a7  Top 10 Regions  927e45e69d461b540a95
# 7   ReportSection7b10a3902b9749b440a7  Top 10 Regions  e62be78fd1927715954c
# 8   ReportSection7b10a3902b9749b440a7  Top 10 Regions  202621bb57dc32d01de1
# 9   ReportSection7b10a3902b9749b440a7  Top 10 Regions  d5bb72270298244906a5
# 10  ReportSection7b10a3902b9749b440a7  Top 10 Regions  9fafd9435a0cc51a9333
# 11  ReportSection7b10a3902b9749b440a7  Top 10 Regions  4a2a265801b28098d91a
# 14  ReportSection7b10a3902b9749b440a7  Top 10 Regions  22d233e1510db7d1c3a4
# 25  ReportSection7b10a3902b9749b440a7  Top 10 Regions  7431bd1ddf78313f3a1b
# 37  ReportSection7b10a3902b9749b440a7  Top 10 Regions      VisualContainer3
# 38  ReportSection7b10a3902b9749b440a7  Top 10 Regions      VisualContainer1
#
#            Visualization                                              Title
# 0                   card                                       Outlet Sales
# 1           multiRowCard                                     Multi-row card
# 2           multiRowCard                                     Multi-row card
# 3           multiRowCard                                     Multi-row card
# 4           multiRowCard                                     Multi-row card
# 5           multiRowCard                                     Multi-row card
# 6                   card                                       Stores Sales
# 7                   card                                 Social Media Sales
# 8                   card                                       Online Sales
# 9                   card                                        Total Sales
# 10                   map           Total Sales and ROI by State and Channel
# 11               treemap                   Total Sales by Channel and State
# 14              barChart  % Units Market Share R12M and % Units Market S...
# 25                 image                                              Image
# 37             lineChart  % Units Market Share R12M and % Units Market S...
# 38  clusteredColumnChart         Total Units by Year, Month and isVanArsdel

# %%
dont_consider = ["actionButton", "basicShape", "shape", "textbox"]
df3 = df[~df["Visualization"].isin(dont_consider)]
df3
# Out:
#                               Page_id             Page_Name  \
# 0   ReportSectionaf0a35f32177070e5614  Return on Investment
# 10  ReportSectionaf0a35f32177070e5614  Return on Investment
# 11  ReportSectionaf0a35f32177070e5614  Return on Investment
# 12  ReportSectionaf0a35f32177070e5614  Return on Investment
# 13  ReportSectionaf0a35f32177070e5614  Return on Investment
# 14  ReportSectionaf0a35f32177070e5614  Return on Investment
# 15  ReportSectionaf0a35f32177070e5614  Return on Investment
# 18  ReportSectionaf0a35f32177070e5614  Return on Investment
# 19  ReportSectionaf0a35f32177070e5614  Return on Investment
# 20  ReportSectionaf0a35f32177070e5614  Return on Investment
# 21  ReportSectionaf0a35f32177070e5614  Return on Investment
# 24  ReportSectionaf0a35f32177070e5614  Return on Investment
# 25  ReportSectionaf0a35f32177070e5614  Return on Investment
# 26  ReportSectionaf0a35f32177070e5614  Return on Investment
# 27  ReportSectionaf0a35f32177070e5614  Return on Investment
# 28  ReportSectionaf0a35f32177070e5614  Return on Investment
# 32  ReportSectionaf0a35f32177070e5614  Return on Investment
# 33  ReportSectionaf0a35f32177070e5614  Return on Investment
# 34  ReportSectionaf0a35f32177070e5614  Return on Investment
# 37  ReportSectionaf0a35f32177070e5614  Return on Investment
# 48  ReportSectionaf0a35f32177070e5614  Return on Investment
# 59  ReportSectionaf0a35f32177070e5614  Return on Investment
# 61  ReportSectionaf0a35f32177070e5614  Return on Investment
# 62  ReportSectionaf0a35f32177070e5614  Return on Investment
#
#                Visual_ID                Visualization  \
# 0   dcfe8fa029be4d09d19d                         card
# 10  2055a9552d55309a00a3                     barChart
# 11  387f678daba1da7c743b                         card
# 12  2981d08ed8a0d96e9d52                     barChart
# 13  745641610271ba1783b2                          map
# 14  c78f9626d517e12ce57e                        gauge
# 15  341bbe841c530182663e  lineStackedColumnComboChart
# 18  63c060122930163c4bea  lineStackedColumnComboChart
# 19  8c95cb70709022447714                        gauge
# 20  193cc3df5d4a2cd04355                          map
# 21  7b58a02931b19d40a910                         card
# 24  2bc557826ac620ce4639                         card
# 25  769f10b9a1e29a389885                     barChart
# 26  42f96cb70b3703e50377                          map
# 27  b912d093940d97507ca6                        gauge
# 28  b0e14884d5502e0038b1  lineStackedColumnComboChart
# 32  83efef8e63ee06c9615e                     barChart
# 33  60a0d2e43199c5c1c2ac                          map
# 34  e8fa5953ab7d8a9cb999                        gauge
# 37  22d233e1510db7d1c3a4                     barChart
# 48  7431bd1ddf78313f3a1b                        image
# 59      VisualContainer6  lineStackedColumnComboChart
# 61      VisualContainer3                    lineChart
# 62      VisualContainer1         clusteredColumnChart
#
#                                                 Title
# 0                                                Card
# 10                                     ROI by Product
# 11                                               Card
# 12                                     ROI by Product
# 13                                       ROI by State
# 14                         Return on Investment (ROI)
# 15                            Sales and ROI Over Time
# 18                            Sales and ROI Over Time
# 19                         Return on Investment (ROI)
# 20                                       ROI by State
# 21                                               Card
# 24                                               Card
# 25                                     ROI by Product
# 26                                       ROI by State
# 27                         Return on Investment (ROI)
# 28                            Sales and ROI Over Time
# 32                                     ROI by Product
# 33                                       ROI by State
# 34                         Return on Investment (ROI)
# 37  % Units Market Share R12M and % Units Market S...
# 48                                              Image
# 59                            Sales and ROI Over Time
# 61  % Units Market Share R12M and % Units Market S...
# 62         Total Units by Year, Month and isVanArsdel

# %%
df4 = pd.concat([df1, df2, df3], ignore_index = True)
file_path_1 = os.path.join(folder_name, f"POC_Competetive_Marketing_VisualMetaData.csv")
df4.to_csv(file_path_1)

# %%
df4
# Out:
#                               Page_id             Page_Name  \
# 0   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 1   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 2   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 3   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 4   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 5   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 6   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 7   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 8   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 9   ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 10  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 11  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 12  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 13  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 14  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 15  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 16  ReportSectione0912ffb2ba909ea50d0    Executive Overview
# 17  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 18  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 19  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 20  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 21  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 22  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 23  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 24  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 25  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 26  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 27  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 28  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 29  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 30  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 31  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 32  ReportSection7b10a3902b9749b440a7        Top 10 Regions
# 33  ReportSectionaf0a35f32177070e5614  Return on Investment
# 34  ReportSectionaf0a35f32177070e5614  Return on Investment
# 35  ReportSectionaf0a35f32177070e5614  Return on Investment
# 36  ReportSectionaf0a35f32177070e5614  Return on Investment
# 37  ReportSectionaf0a35f32177070e5614  Return on Investment
# 38  ReportSectionaf0a35f32177070e5614  Return on Investment
# 39  ReportSectionaf0a35f32177070e5614  Return on Investment
# 40  ReportSectionaf0a35f32177070e5614  Return on Investment
# 41  ReportSectionaf0a35f32177070e5614  Return on Investment
# 42  ReportSectionaf0a35f32177070e5614  Return on Investment
# 43  ReportSectionaf0a35f32177070e5614  Return on Investment
# 44  ReportSectionaf0a35f32177070e5614  Return on Investment
# 45  ReportSectionaf0a35f32177070e5614  Return on Investment
# 46  ReportSectionaf0a35f32177070e5614  Return on Investment
# 47  ReportSectionaf0a35f32177070e5614  Return on Investment
# 48  ReportSectionaf0a35f32177070e5614  Return on Investment
# 49  ReportSectionaf0a35f32177070e5614  Return on Investment
# 50  ReportSectionaf0a35f32177070e5614  Return on Investment
# 51  ReportSectionaf0a35f32177070e5614  Return on Investment
# 52  ReportSectionaf0a35f32177070e5614  Return on Investment
# 53  ReportSectionaf0a35f32177070e5614  Return on Investment
# 54  ReportSectionaf0a35f32177070e5614  Return on Investment
# 55  ReportSectionaf0a35f32177070e5614  Return on Investment
# 56  ReportSectionaf0a35f32177070e5614  Return on Investment
#
#                Visual_ID                Visualization  \
# 0   01e0089059a26da6b0a9                 multiRowCard
# 1       VisualContainer6  lineStackedColumnComboChart
# 2   8c4d5fd430d238c80232                 multiRowCard
# 3   383aeb4a890ab3b0602c                 multiRowCard
# 4   c1fcec8fbd3489c06b5c                 multiRowCard
# 5   c6f0f21b6e8eeeca780e                 multiRowCard
# 6   b3ce93b93cba452a50d4                   donutChart
# 7   601d2ae47d1962782c20                         card
# 8   beef72ba5205ba2613d1                         card
# 9   bfabe4ecb6017dc44b75                         card
# 10  6e130c7362a050c78ee3                         card
# 11  918a74069a7dac914785                         card
# 12  22d233e1510db7d1c3a4                     barChart
# 13  7431bd1ddf78313f3a1b                        image
# 14      VisualContainer4                     barChart
# 15      VisualContainer3                    lineChart
# 16      VisualContainer1         clusteredColumnChart
# 17  25c7bcab60c1e6a83e95                         card
# 18  6dcbb33b0023ad4a8b7d                 multiRowCard
# 19  411d5777020c9b511dee                 multiRowCard
# 20  90df334e48300593891d                 multiRowCard
# 21  c880775270c2c6801780                 multiRowCard
# 22  69cd67e0bdd308b1910c                 multiRowCard
# 23  927e45e69d461b540a95                         card
# 24  e62be78fd1927715954c                         card
# 25  202621bb57dc32d01de1                         card
# 26  d5bb72270298244906a5                         card
# 27  9fafd9435a0cc51a9333                          map
# 28  4a2a265801b28098d91a                      treemap
# 29  22d233e1510db7d1c3a4                     barChart
# 30  7431bd1ddf78313f3a1b                        image
# 31      VisualContainer3                    lineChart
# 32      VisualContainer1         clusteredColumnChart
# 33  dcfe8fa029be4d09d19d                         card
# 34  2055a9552d55309a00a3                     barChart
# 35  387f678daba1da7c743b                         card
# 36  2981d08ed8a0d96e9d52                     barChart
# 37  745641610271ba1783b2                          map
# 38  c78f9626d517e12ce57e                        gauge
# 39  341bbe841c530182663e  lineStackedColumnComboChart
# 40  63c060122930163c4bea  lineStackedColumnComboChart
# 41  8c95cb70709022447714                        gauge
# 42  193cc3df5d4a2cd04355                          map
# 43  7b58a02931b19d40a910                         card
# 44  2bc557826ac620ce4639                         card
# 45  769f10b9a1e29a389885                     barChart
# 46  42f96cb70b3703e50377                          map
# 47  b912d093940d97507ca6                        gauge
# 48  b0e14884d5502e0038b1  lineStackedColumnComboChart
# 49  83efef8e63ee06c9615e                     barChart
# 50  60a0d2e43199c5c1c2ac                          map
# 51  e8fa5953ab7d8a9cb999                        gauge
# 52  22d233e1510db7d1c3a4                     barChart
# 53  7431bd1ddf78313f3a1b                        image
# 54      VisualContainer6  lineStackedColumnComboChart
# 55      VisualContainer3                    lineChart
# 56      VisualContainer1         clusteredColumnChart
#
#                                                 Title
# 0                                      Multi-row card
# 1                    Total Sales by Channel Over Time
# 2                                      Multi-row card
# 3                                      Multi-row card
# 4                                      Multi-row card
# 5                                      Multi-row card
# 6                              Total Sales by Channel
# 7                                        Outlet Sales
# 8                                        Stores Sales
# 9                                  Social Media Sales
# 10                                       Online Sales
# 11                                        Total Sales
# 12  % Units Market Share R12M and % Units Market S...
# 13                                              Image
# 14                 Total Sales by Product and Channel
# 15  % Units Market Share R12M and % Units Market S...
# 16         Total Units by Year, Month and isVanArsdel
# 17                                       Outlet Sales
# 18                                     Multi-row card
# 19                                     Multi-row card
# 20                                     Multi-row card
# 21                                     Multi-row card
# 22                                     Multi-row card
# 23                                       Stores Sales
# 24                                 Social Media Sales
# 25                                       Online Sales
# 26                                        Total Sales
# 27           Total Sales and ROI by State and Channel
# 28                   Total Sales by Channel and State
# 29  % Units Market Share R12M and % Units Market S...
# 30                                              Image
# 31  % Units Market Share R12M and % Units Market S...
# 32         Total Units by Year, Month and isVanArsdel
# 33                                               Card
# 34                                     ROI by Product
# 35                                               Card
# 36                                     ROI by Product
# 37                                       ROI by State
# 38                         Return on Investment (ROI)
# 39                            Sales and ROI Over Time
# 40                            Sales and ROI Over Time
# 41                         Return on Investment (ROI)
# 42                                       ROI by State
# 43                                               Card
# 44                                               Card
# 45                                     ROI by Product
# 46                                       ROI by State
# 47                         Return on Investment (ROI)
# 48                            Sales and ROI Over Time
# 49                                     ROI by Product
# 50                                       ROI by State
# 51                         Return on Investment (ROI)
# 52  % Units Market Share R12M and % Units Market S...
# 53                                              Image
# 54                            Sales and ROI Over Time
# 55  % Units Market Share R12M and % Units Market S...
# 56         Total Units by Year, Month and isVanArsdel

# %%
Page_id_list = list(df4["Page_id"])
Visual_ID_list = list(df4["Visual_ID"])
Page_Name_list = list(df4["Page_Name"])
Title_list = list(df4["Title"])
Visualization_list = list(df4["Visualization"])

# %%
main_column_list = []

# %%
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
for i in range(len(Page_id_list)):
    try:
        viz_data=report.export_visual_data(Page_id_list[i],Visual_ID_list[i])
        file_path_2 = os.path.join(folder_name, f"POC_Competetive_Marketing_{Page_Name_list[i]}_{Title_list[i]}.csv")
        with open(file_path_2, "w") as file:
            file.write(viz_data)
        dummy2 = pd.read_csv(file_path_2)
        if "Unnamed: 0" in dummy2:
            dummy2.drop(columns = "Unnamed: 0", axis = 1, inplace = True)
        dummy3_columns = dummy2.columns.tolist()
        main_column_list.append(dummy3_columns)
        dummy2.to_csv(file_path_2)
    except:
        pass

# %%
main_column_list
# Out:
# [['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Return on Investment (ROI)'],
#  ['State', 'ROI', 'Sales'],
#  ['ROI'],
#  ['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['% Units Market Share', '% Units Market Share R12M'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Year',
#   'Quarter',
#   'Month',
#   'Day',
#   '% Units Market Share',
#   '% Units Market Share R12M'],
#  ['Year', 'Month', 'Day', 'isVanArsdel', 'Total Units'],
#  ['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Return on Investment (ROI)'],
#  ['State', 'ROI', 'Sales'],
#  ['ROI'],
#  ['ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Manufacturer', 'Product', 'ROI'],
#  ['State', 'ROI', 'Sales'],
#  ['Return on Investment (ROI)'],
#  ['% Units Market Share', '% Units Market Share R12M'],
#  ['Months', 'Total Sales', 'ROI'],
#  ['Year',
#   'Quarter',
#   'Month',
#   'Day',
#   '% Units Market Share',
#   '% Units Market Share R12M'],
#  ['Year', 'Month', 'Day', 'isVanArsdel', 'Total Units'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['Social Media Sales'],
#  ['Online Sales'],
#  ['KPI01'],
#  ['State', 'Channel (Map View)', 'Total Sales', 'ROI'],
#  ['Channel', 'Total Sales', 'State (Treemap)'],
#  ['% Units Market Share', '% Units Market Share R12M'],
#  ['Year',
#   'Quarter',
#   'Month',
#   'Day',
#   '% Units Market Share',
#   '% Units Market Share R12M'],
#  ['Year', 'Month', 'Day', 'isVanArsdel', 'Total Units'],
#  ['KPI01'],
#  ['Channel', 'Months', 'Total Sales'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['KPI01'],
#  ['Channel', 'Total Sales'],
#  ['KPI01'],
#  ['KPI01'],
#  ['Social Media Sales'],
#  ['Online Sales'],
#  ['KPI01'],
#  ['% Units Market Share', '% Units Market Share R12M'],
#  ['Product', 'Total Category Volume', 'Channel'],
#  ['Year',
#   'Quarter',
#   'Month',
#   'Day',
#   '% Units Market Share',
#   '% Units Market Share R12M'],
#  ['Year', 'Month', 'Day', 'isVanArsdel', 'Total Units']]

# %%
main_column_list2 = [', '.join(map(str, sublist)) for sublist in main_column_list]
main_column_series = pd.Series(main_column_list2)
columns_for_description = list(zip(Title_list, Visualization_list, main_column_series))
df5 = pd.DataFrame(columns_for_description, columns = ["Visual_Title", "Visual_Type", "Columns"])

# %%
file_path_3 = os.path.join(folder_name, f"POC_Competetive_Marketing_MasterData.csv")
df5.to_csv(file_path_3)

# %%
df5
# Out:
#                                          Visual_Title  \
# 0                                      Multi-row card
# 1                    Total Sales by Channel Over Time
# 2                                      Multi-row card
# 3                                      Multi-row card
# 4                                      Multi-row card
# 5                                      Multi-row card
# 6                              Total Sales by Channel
# 7                                        Outlet Sales
# 8                                        Stores Sales
# 9                                  Social Media Sales
# 10                                       Online Sales
# 11                                        Total Sales
# 12  % Units Market Share R12M and % Units Market S...
# 13                                              Image
# 14                 Total Sales by Product and Channel
# 15  % Units Market Share R12M and % Units Market S...
# 16         Total Units by Year, Month and isVanArsdel
# 17                                       Outlet Sales
# 18                                     Multi-row card
# 19                                     Multi-row card
# 20                                     Multi-row card
# 21                                     Multi-row card
# 22                                     Multi-row card
# 23                                       Stores Sales
# 24                                 Social Media Sales
# 25                                       Online Sales
# 26                                        Total Sales
# 27           Total Sales and ROI by State and Channel
# 28                   Total Sales by Channel and State
# 29  % Units Market Share R12M and % Units Market S...
# 30                                              Image
# 31  % Units Market Share R12M and % Units Market S...
# 32         Total Units by Year, Month and isVanArsdel
# 33                                               Card
# 34                                     ROI by Product
# 35                                               Card
# 36                                     ROI by Product
# 37                                       ROI by State
# 38                         Return on Investment (ROI)
# 39                            Sales and ROI Over Time
# 40                            Sales and ROI Over Time
# 41                         Return on Investment (ROI)
# 42                                       ROI by State
# 43                                               Card
# 44                                               Card
# 45                                     ROI by Product
# 46                                       ROI by State
# 47                         Return on Investment (ROI)
# 48                            Sales and ROI Over Time
# 49                                     ROI by Product
# 50                                       ROI by State
# 51                         Return on Investment (ROI)
# 52  % Units Market Share R12M and % Units Market S...
# 53                                              Image
# 54                            Sales and ROI Over Time
# 55  % Units Market Share R12M and % Units Market S...
# 56         Total Units by Year, Month and isVanArsdel
#
#                     Visual_Type  \
# 0                  multiRowCard
# 1   lineStackedColumnComboChart
# 2                  multiRowCard
# 3                  multiRowCard
# 4                  multiRowCard
# 5                  multiRowCard
# 6                    donutChart
# 7                          card
# 8                          card
# 9                          card
# 10                         card
# 11                         card
# 12                     barChart
# 13                        image
# 14                     barChart
# 15                    lineChart
# 16         clusteredColumnChart
# 17                         card
# 18                 multiRowCard
# 19                 multiRowCard
# 20                 multiRowCard
# 21                 multiRowCard
# 22                 multiRowCard
# 23                         card
# 24                         card
# 25                         card
# 26                         card
# 27                          map
# 28                      treemap
# 29                     barChart
# 30                        image
# 31                    lineChart
# 32         clusteredColumnChart
# 33                         card
# 34                     barChart
# 35                         card
# 36                     barChart
# 37                          map
# 38                        gauge
# 39  lineStackedColumnComboChart
# 40  lineStackedColumnComboChart
# 41                        gauge
# 42                          map
# 43                         card
# 44                         card
# 45                     barChart
# 46                          map
# 47                        gauge
# 48  lineStackedColumnComboChart
# 49                     barChart
# 50                          map
# 51                        gauge
# 52                     barChart
# 53                        image
# 54  lineStackedColumnComboChart
# 55                    lineChart
# 56         clusteredColumnChart
#
#                                               Columns
# 0                                                 ROI
# 1                          Manufacturer, Product, ROI
# 2                                                 ROI
# 3                          Manufacturer, Product, ROI
# 4                                   State, ROI, Sales
# 5                          Return on Investment (ROI)
# 6                            Months, Total Sales, ROI
# 7                            Months, Total Sales, ROI
# 8                          Return on Investment (ROI)
# 9                                   State, ROI, Sales
# 10                                                ROI
# 11                                                ROI
# 12                         Manufacturer, Product, ROI
# 13                                  State, ROI, Sales
# 14                         Return on Investment (ROI)
# 15                           Months, Total Sales, ROI
# 16                         Manufacturer, Product, ROI
# 17                                  State, ROI, Sales
# 18                         Return on Investment (ROI)
# 19    % Units Market Share, % Units Market Share R12M
# 20                           Months, Total Sales, ROI
# 21  Year, Quarter, Month, Day, % Units Market Shar...
# 22         Year, Month, Day, isVanArsdel, Total Units
# 23                                                ROI
# 24                         Manufacturer, Product, ROI
# 25                                                ROI
# 26                         Manufacturer, Product, ROI
# 27                                  State, ROI, Sales
# 28                         Return on Investment (ROI)
# 29                           Months, Total Sales, ROI
# 30                           Months, Total Sales, ROI
# 31                         Return on Investment (ROI)
# 32                                  State, ROI, Sales
# 33                                                ROI
# 34                                                ROI
# 35                         Manufacturer, Product, ROI
# 36                                  State, ROI, Sales
# 37                         Return on Investment (ROI)
# 38                           Months, Total Sales, ROI
# 39                         Manufacturer, Product, ROI
# 40                                  State, ROI, Sales
# 41                         Return on Investment (ROI)
# 42    % Units Market Share, % Units Market Share R12M
# 43                           Months, Total Sales, ROI
# 44  Year, Quarter, Month, Day, % Units Market Shar...
# 45         Year, Month, Day, isVanArsdel, Total Units
# 46                                              KPI01
# 47                                              KPI01
# 48                                              KPI01
# 49                                              KPI01
# 50                                              KPI01
# 51                                              KPI01
# 52                                              KPI01
# 53                                 Social Media Sales
# 54                                       Online Sales
# 55                                              KPI01
# 56        State, Channel (Map View), Total Sales, ROI

# %%
import os
import openai

# %%
file_path_3 = os.path.join(folder_name, f"POC_Store_Sales_MasterData.csv")
df5 = pd.read_csv(file_path_3)
if "Unnamed: 0" in df5:
    df5.drop(columns = "Unnamed: 0", axis = 1, inplace = True)
df5[:3]
# Out:
#                                    Visual_Title   Visual_Type  \
# 0                                Multi-row card  multiRowCard
# 1                                Multi-row card  multiRowCard
# 2  This Year Sales by PostalCode and Store Type           map
#
#                                    Columns
# 0                               New Stores
# 1                          Last Year Sales
# 2  PostalCode, Store Type, This Year Sales

# %%
def api_call(rec_list):
    openai.api_key = "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"
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": f"""Provide the short description in a paragraph for the Power bi visual {rec_list[0]} which is of type {rec_list[1]} consisting of following columns: {rec_list[2]}"""},
        ],
        temperature=0.3,
        max_tokens=1024
    )
    
    return response['choices'][0]['message']['content']

outlier_list = ['Sorry', 'sorry', 'no direct translation', 'cannot', 'not possible', 'Unfortunately', 'unfortunately']

# %%
responses = []
for i in range(len(df5)):
    rec_list= list(df5.iloc[i])
    print(rec_list)
    res_output = api_call(rec_list)
    responses.append(res_output)
# Out:
# ['Multi-row card', 'multiRowCard', 'New Stores']
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[26], line 5
#       3 rec_list= list(df5.iloc[i])
#       4 print(rec_list)
# ----> 5 res_output = api_call(rec_list)
#       6 responses.append(res_output)
#
# Cell In[25], line 3, in api_call(rec_list)
#       1 def api_call(rec_list):
#       2     openai.api_key = "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"
# ----> 3     response = openai.ChatCompletion.create(
#       4         model="gpt-3.5-turbo",
#       5         messages=[
#       6             {"role": "system", "content": f"""Provide the short description in a paragraph for the Power bi visual {rec_list[0]} which is of type {rec_list[1]} consisting of following columns: {rec_list[2]}"""},
#       7         ],
#       8         temperature=0.3,
#       9         max_tokens=1024
#      10     )
#      12     return response['choices'][0]['message']['content']
#
# File ~\Anaconda3\lib\site-packages\openai\_utils\_proxy.py:22, in LazyProxy.__getattr__(self, attr)
#      21 def __getattr__(self, attr: str) -> object:
# ---> 22     return getattr(self.__get_proxied__(), attr)
#
# File ~\Anaconda3\lib\site-packages\openai\_utils\_proxy.py:43, in LazyProxy.__get_proxied__(self)
#      41 def __get_proxied__(self) -> T:
#      42     if not self.should_cache:
# ---> 43         return self.__load__()
#      45     proxied = self.__proxied
#      46     if proxied is not None:
#
# File ~\Anaconda3\lib\site-packages\openai\lib\_old_api.py:33, in APIRemovedInV1Proxy.__load__(self)
#      31 @override
#      32 def __load__(self) -> None:
# ---> 33     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %%
responses[0]
# Out:
# 'The Power BI visual Slicer is a type of slicer that allows users to filter data based on the Sales Region column. This visual provides a user-friendly interface for selecting and filtering data by different sales regions. Users can easily choose one or multiple sales regions to view specific data related to those regions. This slicer is particularly useful for analyzing and comparing sales performance across different regions.'

# %%
df5["Description"] = responses
file_path_1 = os.path.join(folder_name, f"POC_Corporate_Spend_VisualMetaData.csv")
df6 = pd.read_csv(file_path_1)
df5["Page_Name"] = df6["Page_Name"]
df5["Report_Name"] = folder_name
file_path_4 = os.path.join(folder_name, f"POC_Corporate_Spend_MasterData_Description.csv")
#df5.to_csv(file_path_4)
df5
# Out:
#                                  Title                         Type  \
# 0                               Slicer                       slicer
# 1   Actual by Period and Business Area             stackedAreaChart
# 2                   Decomposition tree      decompositionTreeVisual
# 3         Var Plan % by Country/Region                    filledMap
# 4           Actual and Plan by IT Area  lineStackedColumnComboChart
# 5                               Slicer                       slicer
# 6                           Var Plan %                         card
# 7                            Var LE1 %                         card
# 8                            Var LE2 %                         card
# 9                            Var LE3 %                         card
# 10          Var Plan by Country/Region            clusteredBarChart
# 11                              Matrix                   pivotTable
#
#                                               Columns  \
# 0                                        Sales Region
# 1                       Period, Business Area, Actual
# 2   Var Plan, Sales Region, Period, IT Area, IT Su...
# 3                  IT Area, IT Sub Area, Actual, Plan
# 4                                        Sales Region
# 5                                          Var Plan %
# 6                                           Var LE1 %
# 7                                           Var LE2 %
# 8                                           Var LE3 %
# 9                    Month, Business Area, Var Plan %
# 10                          Business Area, Var Plan %
# 11                            Business Area, Var Plan
#
#                                             Responses               Page_Name  \
# 0   The Power BI visual Slicer is a type of slicer...          IT Spend Trend
# 1   The Power BI visual "Actual by Period and Busi...          IT Spend Trend
# 2   The Decomposition Tree visual in Power BI is a...          IT Spend Trend
# 3   The Power BI visual "Var Plan % by Country/Reg...          IT Spend Trend
# 4   The Power BI visual Actual and Plan by IT Area...          IT Spend Trend
# 5   The Power BI visual Slicer is a type of slicer...  Plan Variance Analysis
# 6   The Var Plan % Power BI visual is a card visua...  Plan Variance Analysis
# 7   The Power BI visual Var LE1 % is a card visual...  Plan Variance Analysis
# 8   The Power BI visual Var LE2 % is a card visual...  Plan Variance Analysis
# 9   The Power BI visual Var LE3 % is a card visual...  Plan Variance Analysis
# 10  The Power BI visual Var Plan by Country/Region...  Plan Variance Analysis
# 11  The Power BI visual Matrix is a type of pivot ...  Plan Variance Analysis
#
#             Report_Name
# 0   POC_Corporate_Spend
# 1   POC_Corporate_Spend
# 2   POC_Corporate_Spend
# 3   POC_Corporate_Spend
# 4   POC_Corporate_Spend
# 5   POC_Corporate_Spend
# 6   POC_Corporate_Spend
# 7   POC_Corporate_Spend
# 8   POC_Corporate_Spend
# 9   POC_Corporate_Spend
# 10  POC_Corporate_Spend
# 11  POC_Corporate_Spend

# %%
desired_order = ["Report_Name", "Page_Name", "Title", "Type", "Columns", "Responses"]
df7 = df5[desired_order]
df7.to_csv(file_path_4)
df7
# Out:
#             Report_Name               Page_Name  \
# 0   POC_Corporate_Spend          IT Spend Trend
# 1   POC_Corporate_Spend          IT Spend Trend
# 2   POC_Corporate_Spend          IT Spend Trend
# 3   POC_Corporate_Spend          IT Spend Trend
# 4   POC_Corporate_Spend          IT Spend Trend
# 5   POC_Corporate_Spend  Plan Variance Analysis
# 6   POC_Corporate_Spend  Plan Variance Analysis
# 7   POC_Corporate_Spend  Plan Variance Analysis
# 8   POC_Corporate_Spend  Plan Variance Analysis
# 9   POC_Corporate_Spend  Plan Variance Analysis
# 10  POC_Corporate_Spend  Plan Variance Analysis
# 11  POC_Corporate_Spend  Plan Variance Analysis
#
#                                  Title                         Type  \
# 0                               Slicer                       slicer
# 1   Actual by Period and Business Area             stackedAreaChart
# 2                   Decomposition tree      decompositionTreeVisual
# 3         Var Plan % by Country/Region                    filledMap
# 4           Actual and Plan by IT Area  lineStackedColumnComboChart
# 5                               Slicer                       slicer
# 6                           Var Plan %                         card
# 7                            Var LE1 %                         card
# 8                            Var LE2 %                         card
# 9                            Var LE3 %                         card
# 10          Var Plan by Country/Region            clusteredBarChart
# 11                              Matrix                   pivotTable
#
#                                               Columns  \
# 0                                        Sales Region
# 1                       Period, Business Area, Actual
# 2   Var Plan, Sales Region, Period, IT Area, IT Su...
# 3                  IT Area, IT Sub Area, Actual, Plan
# 4                                        Sales Region
# 5                                          Var Plan %
# 6                                           Var LE1 %
# 7                                           Var LE2 %
# 8                                           Var LE3 %
# 9                    Month, Business Area, Var Plan %
# 10                          Business Area, Var Plan %
# 11                            Business Area, Var Plan
#
#                                             Responses
# 0   The Power BI visual Slicer is a type of slicer...
# 1   The Power BI visual "Actual by Period and Busi...
# 2   The Decomposition Tree visual in Power BI is a...
# 3   The Power BI visual "Var Plan % by Country/Reg...
# 4   The Power BI visual Actual and Plan by IT Area...
# 5   The Power BI visual Slicer is a type of slicer...
# 6   The Var Plan % Power BI visual is a card visua...
# 7   The Power BI visual Var LE1 % is a card visual...
# 8   The Power BI visual Var LE2 % is a card visual...
# 9   The Power BI visual Var LE3 % is a card visual...
# 10  The Power BI visual Var Plan by Country/Region...
# 11  The Power BI visual Matrix is a type of pivot ...
